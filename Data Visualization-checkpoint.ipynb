# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from plotly.offline import iplot
df = pd.read_csv('Wellbeing_and_lifestyle_data.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-d82433b9c210> in <module>
#       3 get_ipython().run_line_magic('matplotlib', 'inline')
#       4 from plotly.offline import iplot
# ----> 5 df = pd.read_csv('Wellbeing_and_lifestyle_data.csv')
#
# ...

# %%
df.head(10)
df.set_index('Timestamp',inplace=True)

# %%
df.head()
# Out:
#            FRUITS_VEGGIES DAILY_STRESS  PLACES_VISITED  CORE_CIRCLE  \
# Timestamp
# 7/7/15                  3            2               2            5
# 7/7/15                  2            3               4            3
# 7/7/15                  2            3               3            4
# 7/7/15                  3            3              10            3
# 7/7/15                  5            1               3            3
#
#            SUPPORTING_OTHERS  SOCIAL_NETWORK  ACHIEVEMENT  DONATION  \
# Timestamp
# 7/7/15                     0               5            2         0
# 7/7/15                     8              10            5         2
# 7/7/15                     4              10            3         2
# 7/7/15                    10               7            2         5
# 7/7/15                    10               4            2         4
#
#            BMI_RANGE  TODO_COMPLETED  ...  LIVE_VISION  SLEEP_HOURS  \
# Timestamp                             ...
# ...

# %%
type(df.TIME_FOR_PASSION.plot(figsize=(30,30),kind='kde'))
# Out:
# matplotlib.axes._subplots.AxesSubplot
