# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from plotly.offline import iplot

# %%
import cufflinks as cf
import plotly as py
py.offline.init_notebook_mode(connected=True)
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
# ...

# %%
df = pd.read_csv(r'C:\Users\shadab\Downloads\ML Assign\Data Analysis internshala\Statement_SES_2011-12-Enrlment.csv')
df.tail(4)
# Out:
#        Year  All Categories - Class I-V - Boys  \
# 26  2008-09                               70.6
# 27  2009-10                               69.7
# 28  2010-11                               70.1
# 29  2011-12                               72.6
#
#     All Categories - Class I-V - Girls  All Categories - Class I-V - Total  \
# 26                                64.7                               135.3
# 27                                63.9                               133.6
# 28                                64.6                               134.8
# 29                                67.2                               139.9
#
#     All Categories - Class VI-VIII - Boys  \
# 26                                   31.4
# 27                                   31.7
# 28                                   32.7
# 29                                   33.1
#
#     All Categories - Class VI-VIII - Girls  \
# 26                                    27.0
# ...

# %%
df['All Categories - Class I-V - Total']=df['All Categories - Class I-V - Total']/2
df.set_index('Year',inplace=True)

# %%
df.iplot()
# Out:
# <div>
#
#
#             <div id="63cd0a2c-9787-4989-922f-f029e6a0a20e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("63cd0a2c-9787-4989-922f-f029e6a0a20e")) {
#                     Plotly.newPlot(
#                         '63cd0a2c-9787-4989-922f-f029e6a0a20e',
# ...

# %%
import plotly.graph_objs as go 

# type defined is choropleth to 
# plot geographical plots 
data = dict(type = 'choropleth', 
  
            # location: Arizoana, California, Newyork 
            locations = ['Austria', 'India', 'Canada'], 
              
            # States of USA 
            locationmode = 'country names', 
              
            # colorscale can be added as per requirement 
            colorscale = 'Portland', 
              
            # text can be given anything you like 
            text = ['text 1', 'text 2', 'text 3'], 
            z = [1.0, 12.0, 33.0], 
            colorbar = {'title': 'Colorbar Title Goes Here'}) 
              
layout = dict(geo ={'scope': 'world'}) 
  
# passing data dictionary as a list  
choromap = go.Figure(data = [data], layout = layout) 
  
# plotting graph 
iplot(choromap)
# Out:
# <div>
#
#
#             <div id="7f74d543-9769-40d3-8ceb-87ac19ec2c5b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("7f74d543-9769-40d3-8ceb-87ac19ec2c5b")) {
#                     Plotly.newPlot(
#                         '7f74d543-9769-40d3-8ceb-87ac19ec2c5b',
#                         [{"colorbar": {"title": {"text": "Colorbar Title Goes Here"}}, "colorscale": [[0.0, "rgb(12,51,131)"], [0.25, "rgb(10,136,186)"], [0.5, "rgb(242,211,56)"], [0.75, "rgb(242,143,56)"], [1.0, "rgb(217,30,30)"]], "locationmode": "country names", "locations": ["Austria", "India", "Canada"], "text": ["text 1", "text 2", "text 3"], "type": "choropleth", "z": [1.0, 12.0, 33.0]}],
# ...

# %%
builtins.str
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-576be292dd3b> in <module>
# ----> 1 builtins.str
#
# NameError: name 'builtins' is not defined

# %% [markdown]
# # Plot Indian states

# %%
import pandas as pd
import geopandas as gpd

# %%
df = pd.read_csv("C:/Users/shadab/Downloads/ML Assign/Data Analysis internshala/corona_cases.txt",sep='\t')

# %%
df
# Out:
#                        States  Confirmed cases  Deaths
# 0                NCT of Delhi              219     4.0
# 1                     Haryana               43     0.0
# 2                      Kerala              286     2.0
# 3                   Rajasthan              133     0.0
# 4                   Telangana              107     3.0
# 5               Uttar Pradesh              113     2.0
# 6                      Ladakh               14     0.0
# 7                  Tamil Nadu              309     1.0
# 8             Jammu & Kashmir               70     2.0
# 9                      Punjab               46     4.0
# 10                  Karnataka              124     3.0
# 11                Maharashtra              335    16.0
# 12             Andhra Pradesh              132     1.0
# 13                Uttarakhand               10     0.0
# 14                     Odisha                5     0.0
# 15                West Bengal               53     3.0
# ...

# %%
map_df = gpd.read_file("C:/Users/shadab/Downloads/ML Assign/Data Analysis internshala/Indian_States.shp")

# %%
map_df
# Out:
#                        st_nm  \
# 0   Andaman & Nicobar Island
# 1         Arunanchal Pradesh
# 2                      Assam
# 3                      Bihar
# 4                 Chandigarh
# 5               Chhattisgarh
# 6     Dadara & Nagar Havelli
# 7                Daman & Diu
# 8                        Goa
# 9                    Gujarat
# 10                   Haryana
# 11          Himachal Pradesh
# 12           Jammu & Kashmir
# 13                 Jharkhand
# 14                 Karnataka
# 15                    Kerala
# 16               Lakshadweep
# 17            Madhya Pradesh
# 18               Maharashtra
# 19                   Manipur
# 20                 Meghalaya
# 21                   Mizoram
# 22                  Nagaland
# 23              NCT of Delhi
# 24                Puducherry
# 25                    Punjab
# 26                 Rajasthan
# 27                    Sikkim
# 28                Tamil Nadu
# 29                 Telangana
# 30                   Tripura
# ...

# %%
merged = map_df.set_index('st_nm').join(df.set_index('States'))
merged
# Out:
#                                                                    geometry  \
# st_nm
# Andaman & Nicobar Island  MULTIPOLYGON (((93.71976 7.20707, 93.71909 7.2...
# Arunanchal Pradesh        POLYGON ((96.16261 29.38078, 96.16860 29.37432...
# Assam                     MULTIPOLYGON (((89.74323 26.30362, 89.74290 26...
# Bihar                     MULTIPOLYGON (((84.50720 24.26323, 84.50355 24...
# Chandigarh                POLYGON ((76.84147 30.75996, 76.83599 30.73623...
# Chhattisgarh              POLYGON ((83.33532 24.09885, 83.35346 24.09627...
# Dadara & Nagar Havelli    POLYGON ((73.20657 20.12216, 73.20797 20.10650...
# Daman & Diu               MULTIPOLYGON (((72.89335 20.44539, 72.89281 20...
# Goa                       MULTIPOLYGON (((74.11918 14.75344, 74.11350 14...
# Gujarat                   MULTIPOLYGON (((71.70375 20.99958, 71.70375 20...
# Haryana                   POLYGON ((76.85065 30.87512, 76.86594 30.86691...
# ...

# %%
merged["Confirmed cases"] = pd.to_numeric(merged["Confirmed cases"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# pandas\_libs\lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "1 0"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-65-7c1b028e6791> in <module>
# ----> 1 merged["Confirmed cases"] = pd.to_numeric(merged["Confirmed cases"])
#
# ~\Anaconda3\envs\demo\lib\site-packages\pandas\core\tools\numeric.py in to_numeric(arg, errors, downcast)
#     147         coerce_numeric = errors not in ("ignore", "raise")
#     148         try:
# --> 149             values = lib.maybe_convert_numeric(
#     150                 values, set(), coerce_numeric=coerce_numeric
#     151             )
#
# pandas\_libs\lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ...

# %%
merged.fillna(0.0)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-39-211602fafeb8> in <module>
# ----> 1 merged.fillna(0.0)
#
# ~\Anaconda3\envs\demo\lib\site-packages\pandas\core\frame.py in fillna(self, value, method, axis, inplace, limit, downcast)
#    4145         downcast=None,
#    4146     ) -> Optional["DataFrame"]:
# -> 4147         return super().fillna(
#    4148             value=value,
#    4149             method=method,
#
# ~\Anaconda3\envs\demo\lib\site-packages\pandas\core\generic.py in fillna(self, value, method, axis, inplace, limit, downcast)
#    6234
#    6235             elif not is_list_like(value):
# -> 6236                 new_data = self._data.fillna(
#    6237                     value=value, limit=limit, inplace=inplace, downcast=downcast
#    6238                 )
#
# ...

# %%
merged.fillna({'Confirmed cases': 0},inplace=True)
merged.drop(columns='Deaths',inplace=True)
merged
# Out:
#                                                                    geometry  \
# st_nm
# Andaman & Nicobar Island  MULTIPOLYGON (((93.71976 7.20707, 93.71909 7.2...
# Arunanchal Pradesh        POLYGON ((96.16261 29.38078, 96.16860 29.37432...
# Assam                     MULTIPOLYGON (((89.74323 26.30362, 89.74290 26...
# Bihar                     MULTIPOLYGON (((84.50720 24.26323, 84.50355 24...
# Chandigarh                POLYGON ((76.84147 30.75996, 76.83599 30.73623...
# Chhattisgarh              POLYGON ((83.33532 24.09885, 83.35346 24.09627...
# Dadara & Nagar Havelli    POLYGON ((73.20657 20.12216, 73.20797 20.10650...
# Daman & Diu               MULTIPOLYGON (((72.89335 20.44539, 72.89281 20...
# Goa                       MULTIPOLYGON (((74.11918 14.75344, 74.11350 14...
# Gujarat                   MULTIPOLYGON (((71.70375 20.99958, 71.70375 20...
# Haryana                   POLYGON ((76.85065 30.87512, 76.86594 30.86691...
# ...

# %%
type(merged)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
merged.plot(figsize=(7,7),column='Confirmed cases',cmap='YlOrRd')
# Out:
# C:\Users\shadab\Anaconda3\envs\demo\lib\site-packages\matplotlib\colors.py:527: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
